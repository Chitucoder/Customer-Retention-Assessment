# %%
import sqlalchemy
from sqlalchemy import create_engine, Column, Integer, String,text
from sqlalchemy.orm import declarative_base, sessionmaker
import pandas as pd

# %%
engine = create_engine("sqlite:///CustomerDataBase.db")

# %%
Session = sessionmaker(bind=engine)
session = Session()

# %%
query = text("SELECT * FROM customer")
result = session.execute(query)

# %%
result.fetchall()
# Out:
# [(1, 30.0, 'Female', 39.0, 14.0, 5.0, 18.0, 'Standard', 'Annual', 932.0, 17.0, 1.0),
#  (2, 65.0, 'Female', 49.0, 1.0, 10.0, 8.0, 'Basic', 'Monthly', 557.0, 6.0, 1.0),
#  (3, 55.0, 'Female', 14.0, 4.0, 6.0, 18.0, 'Basic', 'Quarterly', 185.0, 3.0, 1.0),
#  (4, 58.0, 'Male', 38.0, 21.0, 7.0, 7.0, 'Standard', 'Monthly', 396.0, 29.0, 1.0),
#  (5, 23.0, 'Male', 32.0, 20.0, 5.0, 8.0, 'Basic', 'Monthly', 617.0, 20.0, 1.0),
#  (6, 51.0, 'Male', 33.0, 25.0, 9.0, 26.0, 'Premium', 'Annual', 129.0, 8.0, 1.0),
#  (7, 58.0, 'Female', 49.0, 12.0, 3.0, 16.0, 'Standard', 'Quarterly', 821.0, 24.0, 1.0),
#  (8, 55.0, 'Female', 37.0, 8.0, 4.0, 15.0, 'Premium', 'Annual', 445.0, 30.0, 1.0),
#  (9, 39.0, 'Male', 12.0, 5.0, 7.0, 4.0, 'Standard', 'Quarterly', 969.0, 13.0, 1.0),
#  (10, 64.0, 'Female', 3.0, 25.0, 2.0, 11.0, 'Standard', 'Quarterly', 415.0, 29.0, 1.0),
#  (11, 29.0, 'Male', 18.0, 9.0, 0.0, 30.0, 'Premium', 'Quarterly', 930.0, 18.0, 1.0),
# ...

# %%
import sys
print("Jupyter Python:", sys.executable)
# Out:
# Jupyter Python: c:\program files\python\python.exe

# %%
df = pd.read_sql('customer',engine)

# %%
df
# Out:
#         CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0                1  30.0  Female    39.0             14.0            5.0
# 1                2  65.0  Female    49.0              1.0           10.0
# 2                3  55.0  Female    14.0              4.0            6.0
# 3                4  58.0    Male    38.0             21.0            7.0
# 4                5  23.0    Male    32.0             20.0            5.0
# ...            ...   ...     ...     ...              ...            ...
# 505202      505203  45.0  Female    33.0             12.0            6.0
# 505203      505204  37.0    Male     6.0              1.0            5.0
# 505204      505205  25.0    Male    39.0             14.0            8.0
# 505205      505206  50.0  Female    18.0             19.0            7.0
# 505206      505207  52.0  Female    45.0             15.0            9.0
#
#         Payment Delay Subscription Type Contract Length  Total Spend  \
# ...

# %%
df.truncate
# Out:
# <bound method NDFrame.truncate of         CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0                1  30.0  Female    39.0             14.0            5.0
# 1                2  65.0  Female    49.0              1.0           10.0
# 2                3  55.0  Female    14.0              4.0            6.0
# 3                4  58.0    Male    38.0             21.0            7.0
# 4                5  23.0    Male    32.0             20.0            5.0
# ...            ...   ...     ...     ...              ...            ...
# 505202      505203  45.0  Female    33.0             12.0            6.0
# 505203      505204  37.0    Male     6.0              1.0            5.0
# 505204      505205  25.0    Male    39.0             14.0            8.0
# 505205      505206  50.0  Female    18.0             19.0            7.0
# 505206      505207  52.0  Female    45.0             15.0            9.0
#
# ...

# %%
df
# Out:
#         CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0                1  30.0  Female    39.0             14.0            5.0
# 1                2  65.0  Female    49.0              1.0           10.0
# 2                3  55.0  Female    14.0              4.0            6.0
# 3                4  58.0    Male    38.0             21.0            7.0
# 4                5  23.0    Male    32.0             20.0            5.0
# ...            ...   ...     ...     ...              ...            ...
# 505202      505203  45.0  Female    33.0             12.0            6.0
# 505203      505204  37.0    Male     6.0              1.0            5.0
# 505204      505205  25.0    Male    39.0             14.0            8.0
# 505205      505206  50.0  Female    18.0             19.0            7.0
# 505206      505207  52.0  Female    45.0             15.0            9.0
#
#         Payment Delay Subscription Type Contract Length  Total Spend  \
# ...

# %%
query = text("DROP TABLE customer")
result = session.execute(query)

# %%
result

# %%
df = pd.read_csv('random_employee_dataset.csv')

# %%
df
# Out:
#       customer_id  age  gender  tenure  usage_frequency  support_calls  \
# 0               1   56    Male       1               13              0
# 1               2   69  Female      28               28              4
# 2               3   46  Female       6               11              9
# 3               4   32  Female      47               10              4
# 4               5   60    Male      36                7              7
# ...           ...  ...     ...     ...              ...            ...
# 9995         9996   55    Male      42               25              6
# 9996         9997   51  Female      59               11              7
# 9997         9998   57  Female      25                3              2
# 9998         9999   64    Male      17               24              8
# 9999        10000   32  Female      39               24              1
#
#       payment_delay subscription_type contract_length  total_spend  \
# ...

# %%
db_file = "CustomerDataBase.db"
table_name = "customers"
df.to_sql(table_name, con=engine, if_exists="replace", index=False)
# Out:
# 10000

# %%
df = pd.
